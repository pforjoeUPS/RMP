# %% [markdown]
# # QIS Cluster Analysis

# %% [markdown]
# ## Import Libraries

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\RRQ1FYQ\\Documents\\RMP')

# %%
from EquityHedging.datamanager import data_manager as dm
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
import plotly.io as pio
import plotly.express as px
import plotly.offline as py
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster 
import plotly.figure_factory as ff
import plotly.graph_objects as go
from scipy.spatial.distance import pdist, squareform
import ipywidgets as widgets
from ipywidgets import interact

# %% [markdown]
# ## Import Normalized Hedge Metrics

# %%
file_path = dm.EQUITY_HEDGE_DATA+'def_uni_hedge_metrics_more.xlsx'
#normalized_hm = pd.read_excel(dm.EQUITY_HEDGE_DATA+'def_uni_hedge_metrics_more.xlsx', index_col=(0))
normalized_hm = pd.read_excel(dm.QIS_UNIVERSE +'Normalized_Hedge_Metrics.xlsx', index_col=(0))
features = ['Downside Reliability', 'Convexity', 'Cost', 'Decay']
normalized_hm = normalized_hm[features]
normalized_hm.head(20)
# Out:
#                                                     Downside Reliability  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...              0.845629
# Barclays US Small Cap Weekly Var Hourly Index  ...              0.790128
# Barclays Eurozone Weekly Short Var Hourly Index...              0.708328
# Barclays US Long Short Variance Relative Value ...              0.527790
# Barclays VIX Options Risk Premium Series II Str...              0.661711
# Barclays Global Multi-Factor MH EW Index  BXIIW...              0.589812
# Barclays Global Multi-Factor MH EW Index HiC  B...              0.587520
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...              0.590719
# Barclays Global Multi-Factor MH 3x Leveraged  B...              0.591646
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...              0.547069
# Barclays Eurozone Multi-Factor MH EW Index  BXI...              0.574183
# Barclays UK  Multi-Factor MH EW Index  BXIIGFHG...              0.598038
# Barclays Japan Multi-Factor MH EW Index  BXIIJF...              0.476359
# Barclays Global Momentum Market Hedged Index  B...              0.518140
# Barclays US Momentum Equity Market Hedged Index...              0.517216
# Barclays Eurozone Momentum Equity Market Hedged...              0.480531
# Barclays UK Momentum Equity Market Hedged Index...              0.595796
# Barclays Japan Momentum Equity Market Hedged In...              0.482898
# Barclays Global Value Market Hedged Index  BXII...              0.506436
# Barclays US Value Equity Market Hedged Index ER...              0.422807
#
#                                                     Convexity      Cost  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...   0.001556  0.952677
# Barclays US Small Cap Weekly Var Hourly Index  ...   0.001557  0.940718
# Barclays Eurozone Weekly Short Var Hourly Index...   0.001306  0.957960
# Barclays US Long Short Variance Relative Value ...   1.000000  0.000000
# Barclays VIX Options Risk Premium Series II Str...   0.018968  0.885105
# Barclays Global Multi-Factor MH EW Index  BXIIW...   0.001812  0.958770
# Barclays Global Multi-Factor MH EW Index HiC  B...   0.001346  0.958411
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...   0.003914  0.915600
# Barclays Global Multi-Factor MH 3x Leveraged  B...   0.006097  0.872037
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...   0.004272  0.924251
# Barclays Eurozone Multi-Factor MH EW Index  BXI...   0.002810  0.932936
# Barclays UK  Multi-Factor MH EW Index  BXIIGFHG...   0.006687  0.907919
# Barclays Japan Multi-Factor MH EW Index  BXIIJF...   0.002909  0.947768
# Barclays Global Momentum Market Hedged Index  B...   0.003787  0.904587
# Barclays US Momentum Equity Market Hedged Index...   0.004931  0.811920
# Barclays Eurozone Momentum Equity Market Hedged...   0.006355  0.868008
# Barclays UK Momentum Equity Market Hedged Index...   0.003778  0.892204
# Barclays Japan Momentum Equity Market Hedged In...   0.007103  0.855746
# Barclays Global Value Market Hedged Index  BXII...   0.004820  0.914815
# Barclays US Value Equity Market Hedged Index ER...   0.006827  0.818139
#
#                                                        Decay
# Barclays Weekly Short Var Hourly Index  BXIIUWF...  1.000000
# Barclays US Small Cap Weekly Var Hourly Index  ...  1.000000
# Barclays Eurozone Weekly Short Var Hourly Index...  1.000000
# Barclays US Long Short Variance Relative Value ...  0.101370
# Barclays VIX Options Risk Premium Series II Str...  0.687671
# Barclays Global Multi-Factor MH EW Index  BXIIW...  0.531507
# Barclays Global Multi-Factor MH EW Index HiC  B...  0.271233
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...  0.410959
# Barclays Global Multi-Factor MH 3x Leveraged  B...  0.410959
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...  0.063014
# Barclays Eurozone Multi-Factor MH EW Index  BXI...  0.000000
# Barclays UK  Multi-Factor MH EW Index  BXIIGFHG...  0.287671
# Barclays Japan Multi-Factor MH EW Index  BXIIJF...  0.057534
# Barclays Global Momentum Market Hedged Index  B...  0.293151
# Barclays US Momentum Equity Market Hedged Index...  0.079452
# Barclays Eurozone Momentum Equity Market Hedged...  0.068493
# Barclays UK Momentum Equity Market Hedged Index...  0.279452
# Barclays Japan Momentum Equity Market Hedged In...  0.035616
# Barclays Global Value Market Hedged Index  BXII...  0.230137
# Barclays US Value Equity Market Hedged Index ER...  0.065753

# %%
normalized_hm = pd.read_excel(dm.QIS_UNIVERSE + 'Normalized_Hedge_Metrics.xlsx', index_col=0)

features = ['Downside Reliability',  'Convexity', 'Cost', 'Decay']
normalized_hm = normalized_hm[features]

normalized_hm.head(100)
# Out:
#                                                     Downside Reliability  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...              0.845629
# Barclays US Small Cap Weekly Var Hourly Index  ...              0.790128
# Barclays Eurozone Weekly Short Var Hourly Index...              0.708328
# Barclays US Long Short Variance Relative Value ...              0.527790
# Barclays VIX Options Risk Premium Series II Str...              0.661711
# ...                                                                  ...
# Barclays China Equity Intraday Momentum Index  ...              0.467750
# Barclays Australia Equity Intraday Momentum Ind...              0.448056
# Barclays US Long Short Variance Hedging Index  ...              0.526680
# Barclays US Long Short Variance Tail Hedge Inde...              0.517847
# Barclays Dynamic Convexity US Index  BXIIDCNU I...              0.329651
#
#                                                     Convexity      Cost  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...   0.001556  0.952677
# Barclays US Small Cap Weekly Var Hourly Index  ...   0.001557  0.940718
# Barclays Eurozone Weekly Short Var Hourly Index...   0.001306  0.957960
# Barclays US Long Short Variance Relative Value ...   1.000000  0.000000
# Barclays VIX Options Risk Premium Series II Str...   0.018968  0.885105
# ...                                                       ...       ...
# Barclays China Equity Intraday Momentum Index  ...   0.012007  0.900905
# Barclays Australia Equity Intraday Momentum Ind...   0.005627  0.955460
# Barclays US Long Short Variance Hedging Index  ...   0.588517  0.164816
# Barclays US Long Short Variance Tail Hedge Inde...   0.287613  0.389965
# Barclays Dynamic Convexity US Index  BXIIDCNU I...   0.007359  0.977632
#
#                                                        Decay
# Barclays Weekly Short Var Hourly Index  BXIIUWF...  1.000000
# Barclays US Small Cap Weekly Var Hourly Index  ...  1.000000
# Barclays Eurozone Weekly Short Var Hourly Index...  1.000000
# Barclays US Long Short Variance Relative Value ...  0.101370
# Barclays VIX Options Risk Premium Series II Str...  0.687671
# ...                                                      ...
# Barclays China Equity Intraday Momentum Index  ...  0.369863
# Barclays Australia Equity Intraday Momentum Ind...  1.000000
# Barclays US Long Short Variance Hedging Index  ...  0.082192
# Barclays US Long Short Variance Tail Hedge Inde...  0.035616
# Barclays Dynamic Convexity US Index  BXIIDCNU I...  1.000000
#
# [100 rows x 4 columns]

# %%
# Calculate the sum of features for each strategy (row-wise sum)
normalized_hm['Total'] = normalized_hm.sum(axis=1)

normalized_hm.head(100)
# Out:
#                                                     Downside Reliability  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...              0.845629
# Barclays US Small Cap Weekly Var Hourly Index  ...              0.790128
# Barclays Eurozone Weekly Short Var Hourly Index...              0.708328
# Barclays US Long Short Variance Relative Value ...              0.527790
# Barclays VIX Options Risk Premium Series II Str...              0.661711
# ...                                                                  ...
# Barclays China Equity Intraday Momentum Index  ...              0.467750
# Barclays Australia Equity Intraday Momentum Ind...              0.448056
# Barclays US Long Short Variance Hedging Index  ...              0.526680
# Barclays US Long Short Variance Tail Hedge Inde...              0.517847
# Barclays Dynamic Convexity US Index  BXIIDCNU I...              0.329651
#
#                                                     Convexity      Cost  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...   0.001556  0.952677
# Barclays US Small Cap Weekly Var Hourly Index  ...   0.001557  0.940718
# Barclays Eurozone Weekly Short Var Hourly Index...   0.001306  0.957960
# Barclays US Long Short Variance Relative Value ...   1.000000  0.000000
# Barclays VIX Options Risk Premium Series II Str...   0.018968  0.885105
# ...                                                       ...       ...
# Barclays China Equity Intraday Momentum Index  ...   0.012007  0.900905
# Barclays Australia Equity Intraday Momentum Ind...   0.005627  0.955460
# Barclays US Long Short Variance Hedging Index  ...   0.588517  0.164816
# Barclays US Long Short Variance Tail Hedge Inde...   0.287613  0.389965
# Barclays Dynamic Convexity US Index  BXIIDCNU I...   0.007359  0.977632
#
#                                                        Decay     Total
# Barclays Weekly Short Var Hourly Index  BXIIUWF...  1.000000  2.799862
# Barclays US Small Cap Weekly Var Hourly Index  ...  1.000000  2.732403
# Barclays Eurozone Weekly Short Var Hourly Index...  1.000000  2.667594
# Barclays US Long Short Variance Relative Value ...  0.101370  1.629160
# Barclays VIX Options Risk Premium Series II Str...  0.687671  2.253455
# ...                                                      ...       ...
# Barclays China Equity Intraday Momentum Index  ...  0.369863  1.750526
# Barclays Australia Equity Intraday Momentum Ind...  1.000000  2.409142
# Barclays US Long Short Variance Hedging Index  ...  0.082192  1.362205
# Barclays US Long Short Variance Tail Hedge Inde...  0.035616  1.231041
# Barclays Dynamic Convexity US Index  BXIIDCNU I...  1.000000  2.314643
#
# [100 rows x 5 columns]

# %% [markdown]
# # Devang's code

# %%
# Calculate the pairwise distances between strategies
distances = pdist(normalized_hm[features])

# Convert the pairwise distances to a square distance matrix
square_distances = squareform(distances)

# Perform hierarchical clustering using linkage on the square distance matrix
linked = linkage(square_distances, 'ward')

num_clusters = 3

clusters = fcluster(linked, t=num_clusters, criterion='maxclust')

normalized_hm['Cluster'] = clusters


best_strategies = normalized_hm.groupby('Cluster')['Total'].idxmax()

# Get the rows corresponding to the best strategies
best_performing_strategies = normalized_hm.loc[best_strategies]

print("Best Performing Strategies in Each Cluster:")
print(best_performing_strategies)

#  function to display the strategies in the selected cluster
def show_strategies_in_cluster(selected_cluster):
    selected_strategies = normalized_hm[normalized_hm['Cluster'] == selected_cluster].index.tolist()
    print(f"\nCluster {selected_cluster} Strategies:")
    print(selected_strategies)

#  a dropdown widget for selecting different cluster numbers
cluster_dropdown = widgets.Dropdown(
    options=normalized_hm['Cluster'].unique(),
    description='Select Cluster:',
    value=num_clusters,  # Default value is the total number of clusters
)


interact(show_strategies_in_cluster, selected_cluster=cluster_dropdown);
# Out:
# C:\Users\RRQ1FYQ\AppData\Local\Temp/ipykernel_3368/4066322254.py:8: ClusterWarning:
#
# scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
# Best Performing Strategies in Each Cluster:
#                                                     Downside Reliability  \
# UBS Epsilon Theory Narrative Alpha Long-Only St...              0.934067
# BNP TIER US Index  BNPITIU1 Index                               0.944732
# Macquarie US Equity Weekly Volatility Carry Sel...              0.652370
#
#                                                     Convexity      Cost  \
# UBS Epsilon Theory Narrative Alpha Long-Only St...   0.011112  0.842824
# BNP TIER US Index  BNPITIU1 Index                    0.010237  0.933276
# Macquarie US Equity Weekly Volatility Carry Sel...   0.000676  0.987556
#
#                                                        Decay     Total  \
# UBS Epsilon Theory Narrative Alpha Long-Only St...  0.632877  2.420880
# BNP TIER US Index  BNPITIU1 Index                   1.000000  2.888244
# Macquarie US Equity Weekly Volatility Carry Sel...  0.857534  2.498136
#
#                                                     Cluster
# UBS Epsilon Theory Narrative Alpha Long-Only St...        1
# BNP TIER US Index  BNPITIU1 Index                         2
# Macquarie US Equity Weekly Volatility Carry Sel...        3
# interactive(children=(Dropdown(description='Select Cluster:', index=1, options=(2, 3, 1), value=3), Output()),…

# %% [markdown]
# # Maddie's Code

# %%
links = shc.linkage(normalized_hm[features], method = 'ward')
# Set a threshold to determine the number of clusters 
threshold = 3
# You can adjust this value based on your data and requirements

# Retrieve cluster labels for each data point 
clusters = fcluster(links, t = threshold, criterion='distance')

normalized_hm['Cluster'] = list(clusters)
normalized_hm.head(10)
# Out:
#                                                     Downside Reliability  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...              0.845629
# Barclays US Small Cap Weekly Var Hourly Index  ...              0.790128
# Barclays Eurozone Weekly Short Var Hourly Index...              0.708328
# Barclays US Long Short Variance Relative Value ...              0.527790
# Barclays VIX Options Risk Premium Series II Str...              0.661711
# Barclays Global Multi-Factor MH EW Index  BXIIW...              0.589812
# Barclays Global Multi-Factor MH EW Index HiC  B...              0.587520
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...              0.590719
# Barclays Global Multi-Factor MH 3x Leveraged  B...              0.591646
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...              0.547069
#
#                                                     Convexity      Cost  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...   0.001556  0.952677
# Barclays US Small Cap Weekly Var Hourly Index  ...   0.001557  0.940718
# Barclays Eurozone Weekly Short Var Hourly Index...   0.001306  0.957960
# Barclays US Long Short Variance Relative Value ...   1.000000  0.000000
# Barclays VIX Options Risk Premium Series II Str...   0.018968  0.885105
# Barclays Global Multi-Factor MH EW Index  BXIIW...   0.001812  0.958770
# Barclays Global Multi-Factor MH EW Index HiC  B...   0.001346  0.958411
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...   0.003914  0.915600
# Barclays Global Multi-Factor MH 3x Leveraged  B...   0.006097  0.872037
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...   0.004272  0.924251
#
#                                                        Decay     Total  \
# Barclays Weekly Short Var Hourly Index  BXIIUWF...  1.000000  2.799862
# Barclays US Small Cap Weekly Var Hourly Index  ...  1.000000  2.732403
# Barclays Eurozone Weekly Short Var Hourly Index...  1.000000  2.667594
# Barclays US Long Short Variance Relative Value ...  0.101370  1.629160
# Barclays VIX Options Risk Premium Series II Str...  0.687671  2.253455
# Barclays Global Multi-Factor MH EW Index  BXIIW...  0.531507  2.081901
# Barclays Global Multi-Factor MH EW Index HiC  B...  0.271233  1.818510
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...  0.410959  1.921193
# Barclays Global Multi-Factor MH 3x Leveraged  B...  0.410959  1.880740
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...  0.063014  1.538606
#
#                                                     Cluster
# Barclays Weekly Short Var Hourly Index  BXIIUWF...        6
# Barclays US Small Cap Weekly Var Hourly Index  ...        6
# Barclays Eurozone Weekly Short Var Hourly Index...        6
# Barclays US Long Short Variance Relative Value ...        2
# Barclays VIX Options Risk Premium Series II Str...        8
# Barclays Global Multi-Factor MH EW Index  BXIIW...        8
# Barclays Global Multi-Factor MH EW Index HiC  B...        4
# Global Multi-Factor MH 2x Leveraged  BXIIWFH2 I...        8
# Barclays Global Multi-Factor MH 3x Leveraged  B...        4
# Barclays US Multi-Factor MH EW Index  BXIIUFHU ...        1

# %%
best_strategies = normalized_hm.groupby('Cluster')['Total'].idxmax()

# Get the rows corresponding to the best strategies
best_performing_strategies = normalized_hm.loc[best_strategies]

print("Best Performing Strategies in Each Cluster:")
print(best_performing_strategies)
# Out:
# Best Performing Strategies in Each Cluster:
#                                                     Downside Reliability  \
# US Weekly Short Variance Index  BXIIWSVU Index                  0.902237
# Barclays US Long Short Variance Relative Value ...              0.527790
# UBS US Long Short Hourly Variance Balanced  XUB...              0.359822
# Macquarie WTI Intraday Mean Reversion   MQCPR1C...              0.519752
# Citi US Tech Mean Reversion Index  CIEQMUT1 Index               0.544936
# BNP TIER US Index  BNPITIU1 Index                               0.944732
# UBS Epsilon Theory Narrative Alpha Long-Only St...              0.934067
# BNP AIR US 2 TR Index  BNPIAIUS Index                           0.791635
#
#                                                     Convexity      Cost  \
# US Weekly Short Variance Index  BXIIWSVU Index       0.002498  0.934188
# Barclays US Long Short Variance Relative Value ...   1.000000  0.000000
# UBS US Long Short Hourly Variance Balanced  XUB...   0.002107  0.964723
# Macquarie WTI Intraday Mean Reversion   MQCPR1C...   0.030200  0.916743
# Citi US Tech Mean Reversion Index  CIEQMUT1 Index    0.004591  0.967321
# BNP TIER US Index  BNPITIU1 Index                    0.010237  0.933276
# UBS Epsilon Theory Narrative Alpha Long-Only St...   0.011112  0.842824
# BNP AIR US 2 TR Index  BNPIAIUS Index                0.001568  0.964199
#
#                                                        Decay     Total  \
# US Weekly Short Variance Index  BXIIWSVU Index      0.189041  2.027964
# Barclays US Long Short Variance Relative Value ...  0.101370  1.629160
# UBS US Long Short Hourly Variance Balanced  XUB...  0.635616  1.962269
# Macquarie WTI Intraday Mean Reversion   MQCPR1C...  0.476712  1.943407
# Citi US Tech Mean Reversion Index  CIEQMUT1 Index   1.000000  2.516847
# BNP TIER US Index  BNPITIU1 Index                   1.000000  2.888244
# UBS Epsilon Theory Narrative Alpha Long-Only St...  0.632877  2.420880
# BNP AIR US 2 TR Index  BNPIAIUS Index               0.695890  2.453292
#
#                                                     Cluster
# US Weekly Short Variance Index  BXIIWSVU Index            1
# Barclays US Long Short Variance Relative Value ...        2
# UBS US Long Short Hourly Variance Balanced  XUB...        3
# Macquarie WTI Intraday Mean Reversion   MQCPR1C...        4
# Citi US Tech Mean Reversion Index  CIEQMUT1 Index         5
# BNP TIER US Index  BNPITIU1 Index                         6
# UBS Epsilon Theory Narrative Alpha Long-Only St...        7
# BNP AIR US 2 TR Index  BNPIAIUS Index                     8

# %%
#  function to display the strategies in the selected cluster
def show_strategies_in_cluster(selected_cluster):
    selected_strategies = normalized_hm[normalized_hm['Cluster'] == selected_cluster].index.tolist()
    print(f"\nCluster {selected_cluster} Strategies:")
    print(selected_strategies)

#  a dropdown widget for selecting different cluster numbers
cluster_dropdown = widgets.Dropdown(
    options=normalized_hm['Cluster'].unique(),
    description='Select Cluster:',
     # Default value is the total number of clusters
)


interact(show_strategies_in_cluster, selected_cluster=cluster_dropdown);
# Out:
# interactive(children=(Dropdown(description='Select Cluster:', options=(6, 2, 8, 4, 1, 5, 3, 7), value=6), Outp…

# %% [markdown]
# # Create Dendrogram

# %%
# Create the dendrogram figure
dendro_fig = ff.create_dendrogram(links, orientation='bottom')

# Add custom hover text to the dendrogram
dendro_fig.update_traces(hovertext=dendro_fig['data'][0]['text'])

# Customize the layout
dendro_fig.update_layout(width=800, height=700, title='Dendrogram')

# Define a callback function for hover events
def hover_callback(trace, points, state):
    ind = points.point_inds[0]
    cluster_num = clusters[ind]
    strategies = normalized_hm[normalized_hm['Cluster'] == cluster_num].index.tolist()
    tooltip = f"Cluster {cluster_num} Strategies: <br>" + "\n".join(strategies)
    trace.set_hovertext(tooltip)
# Add the callback to the dendrogram
dendro_fig.data[0].on_hover(hover_callback)

# Set the x-axis labels to the names of the strategies
layout = dendro_fig.layout
layout.xaxis.ticktext = normalized_hm.index.tolist()


# Show the dendrogram
dendro_fig.show()

# %% [markdown]
# ## Find what strats are in each cluster
# find what strats rank highest in each cluster
# best in each metric
# best over all

# %%
fig = plt.figure(figsize=(20, 10))
plt.xticks(rotation=45)
dend = shc.dendrogram(links)
# Out:
# Error in callback <function flush_figures at 0x0000027B8E624670> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~\anaconda\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# ~\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# ~\anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~\anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~\anaconda\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# ~\anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~\anaconda\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2879                 artists.remove(spine)
#    2880
# -> 2881         self._update_title_position(renderer)
#    2882
#    2883         if not self.axison or inframe:
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2810                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2811                         or ax.xaxis.get_label_position() == 'top'):
# -> 2812                     bb = ax.xaxis.get_tightbbox(renderer)
#    2813                 else:
#    2814                     bb = ax.get_window_extent(renderer)
#
# ~\anaconda\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1089
#    1090         # go back to just this axis's tick labels
# -> 1091         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1092                     ticks_to_draw, renderer)
#    1093
#
# ~\anaconda\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1066     def _get_tick_bboxes(self, ticks, renderer):
#    1067         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068         return ([tick.label1.get_window_extent(renderer)
#    1069                  for tick in ticks if tick.label1.get_visible()],
#    1070                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1066     def _get_tick_bboxes(self, ticks, renderer):
#    1067         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068         return ([tick.label1.get_window_extent(renderer)
#    1069                  for tick in ticks if tick.label1.get_visible()],
#    1070                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     304
#     305         # Full vertical extent of font, including ascenders and descenders:
# --> 306         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307             "lp", self._fontproperties,
#     308             ismath="TeX" if self.get_usetex() else False)
#
# ~\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     238         flags = get_hinting_flag()
#     239         font = self._get_agg_font(prop)
# --> 240         font.set_text(s, 0.0, flags=flags)
#     241         w, h = font.get_width_height()  # width and height of unrotated string
#     242         d = font.get_descent()
#
# KeyboardInterrupt:

# %%
# Add a callback function to the dendrogram
def on_click(event):
    if event.mouseevent.button == 1:
        ind = event.ind[0]
        cluster_num = clusters[ind]
        strategies = normalized_hm[normalized_hm['Cluster'] == cluster_num].index.tolist()
        print(f"Cluster {cluster_num} Strategies: {strategies}")

fig.canvas.mpl_connect('pick_event', on_click)
plt.show()

# %% [markdown]
# ## Dendrogram

# %% [markdown]
# ## Principal Component Analysis

# %%
pca = PCA(n_components = 2)
X_principal = pca.fit_transform(normalized_hm)

# %%
X_principal = pd.DataFrame(X_principal, index = normalized_hm.index)
X_principal.columns = ['P1', 'P2']

# %%
X_principal

# %% [markdown]
# ## Elbow Method

# %%
inertia = []
K = range(1,6)
for k in K:
    kmeanModel = KMeans(n_clusters=k).fit(normalized_hm)
    kmeanModel.fit(normalized_hm)
    inertia.append(kmeanModel.inertia_)
    
    # Plot the elbow
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ## Determine amount of clusters

# %%
# input clusters here
ncluster = 3

# %%
ac2 = AgglomerativeClustering(n_clusters = ncluster, affinity = 'euclidean', linkage = 'ward')
X_principal['Cluster'] = ac2.fit_predict(X_principal)
X_principal2 = X_principal.copy()
X_principal2['Strat'] = list(X_principal.index)
X_principal2

# %% [markdown]
# ## Agglomerative Clustering

# %%
ac2 = AgglomerativeClustering(n_clusters = ncluster, affinity = 'euclidean', linkage = 'ward')
fig = px.scatter(X_principal2, x= 'P1',y ='P2', 
                 color = ac2.fit_predict(X_principal), hover_data = ['Strat'])
fig

# %%
ac2 = AgglomerativeClustering(n_clusters = ncluster, affinity = 'euclidean', linkage = 'single')
fig = px.scatter( x= X_principal['P1'],y =X_principal['P2'], color = ac2.fit_predict(X_principal))
fig

# %%
ac2 = AgglomerativeClustering(n_clusters = ncluster, affinity = 'euclidean', linkage = 'complete')
fig = px.scatter( x= X_principal['P1'],y =X_principal['P2'], color = ac2.fit_predict(X_principal))
fig

# %%
ac2 = AgglomerativeClustering(n_clusters = ncluster, affinity = 'euclidean', linkage = 'average')
fig = px.scatter( x= X_principal['P1'],y =X_principal['P2'], color = ac2.fit_predict(X_principal))
fig
